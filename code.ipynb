# %% [markdown]
# Importing necesssary libraries

# %%
from elasticsearch import Elasticsearch
from bs4 import BeautifulSoup
import spacy
import os
from datetime import datetime
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from geopy.geocoders import Nominatim

# %%
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# defining an es object

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# Creating the mapping and the setting for the index

# %%
index_mapping = {
    "mappings": {
        "properties": {
            "title": {
                "type": "text",
                "analyzer": "autocomplete",
            },
            "content": {
                "type": "text",
            },
            "authors": {
                "type": "nested",
                "properties": {
                    "name": {"type": "text"},
                },
            },
            "date": {
                "type": "date",
            },
            "geopoint": {
                "type": "geo_point",
            },
            "temporalExpressions": {
                "type": "text",
            },
            "georeferences": {
                "type": "text",
            },
        }
    },
    "settings": {
        "analysis": {
            "analyzer": {
                "autocomplete": {
                    "tokenizer": "autocomplete",
                    "filter": ["lowercase"]
                },
                "autocomplete_search": {
                    "tokenizer": "lowercase"
                }
            },
            "tokenizer": {
                "autocomplete": {
                    "type": "edge_ngram",
                    "min_gram": 1,
                    "max_gram": 25,
                    "token_chars": ["letter", "digit"]
                }
            }
        }
    }
}
es = Elasticsearch(['http://localhost:9200/'])
index_name = "my_index"
es.indices.create(index=index_name, body=index_mapping)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[63], line 55
#      53 es = Elasticsearch(['http://localhost:9200/'])
#      54 index_name = "my_index"
# ---> 55 es.indices.create(index=index_name, body=index_mapping)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\elasticsearch\_sync\client\utils.py:402, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     399         except KeyError:
#     400             pass
# --> 402 return api(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\elasticsearch\_sync\client\indices.py:493, in IndicesClient.create(self, index, aliases, error_trace, filter_path, human, mappings, master_timeout, pretty, settings, timeout, wait_for_active_shards)
#     491 if __body is not None:
#     492     __headers["content-type"] = "application/json"
# --> 493 return self.perform_request(  # type: ignore[return-value]
#     494     "PUT", __path, params=__query, headers=__headers, body=__body
#     495 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\elasticsearch\_sync\client\_base.py:389, in NamespacedClient.perform_request(self, method, path, params, headers, body)
#     378 def perform_request(
#     379     self,
#     380     method: str,
#    (...)
#     387     # Use the internal clients .perform_request() implementation
#     388     # so we take advantage of their transport options.
# --> 389     return self._client.perform_request(
#     390         method, path, params=params, headers=headers, body=body
#     391     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\elasticsearch\_sync\client\_base.py:320, in BaseClient.perform_request(self, method, path, params, headers, body)
#     317         except (ValueError, KeyError, TypeError):
#     318             pass
# --> 320     raise HTTP_EXCEPTIONS.get(meta.status, ApiError)(
#     321         message=message, meta=meta, body=resp_body
#     322     )
#     324 # 'X-Elastic-Product: Elasticsearch' should be on every 2XX response.
#     325 if not self._verified_elasticsearch:
#     326     # If the header is set we mark the server as verified.
#
# BadRequestError: BadRequestError(400, 'resource_already_exists_exception', 'index [my_index/U1GMUIXcSfytVbOgsMyQfQ] already exists')

# %% [markdown]
# Function to extract the of publishing the article

# %%
def extract_date_of_publish(reuters_tag):
    date_tags = reuters_tag.find_all('date')
    
    if date_tags:
        date_tag = date_tags[0]
        date_str = date_tag.text.strip()
        
        
        date_obj = datetime.strptime(date_str, "%d-%b-%Y %H:%M:%S.%f")


    return date_obj

# %% [markdown]
# Function to extract the title

# %%
def extract_article_title(reuters_tag):
    title_tag = reuters_tag.find('title')
    title = title_tag.text.strip() if title_tag else None
    return title

# %% [markdown]
# Function to extract the temporal expressions in the article

# %%
def extract_temporal_expressions(tag):
    body_tag = tag.find('body')
    
    if body_tag:
        content = body_tag.text.strip()
        doc = nlp(content)
        temporal_expressions = [ent.text for ent in doc.ents if ent.label_ == 'DATE']
        return temporal_expressions
    else:
        return None

# %% [markdown]
# Function to extract the authors of the article

# %%
def extract_authors(article_tag):
    authors_tags = article_tag.find_all('author')
    
    authors_list = []
    for author_tag in authors_tags:
        author_name = author_tag.text.strip()
        authors_list.append({"name": author_name})
    
    return authors_list if authors_list else None

# %% [markdown]
# Function to extract the georeferences in the article

# %%
def extract_georeferences(tag):
    content_tag = tag.find('body')
    content = content_tag.text.strip() if content_tag else None

    if content:
        doc = nlp(content)
        georeferences = [ent.text for ent in doc.ents if ent.label_ in ['GPE', 'LOC']]
        return georeferences
    else:
        return

# %% [markdown]
# Function to extract and pre proccesing the content

# %%
def preprocess_body(article_tag):
    body_tag = article_tag.find('body')
    
    body_text = BeautifulSoup(str(body_tag), 'html.parser').get_text()

    # tokenize the content
    words = re.findall(r'\b\w+\b', body_text.lower())

    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word not in stop_words and len(word) >= 3]

    porter = PorterStemmer()
    stemmed_words = [porter.stem(word) for word in filtered_words]

    # join the processed words back into a string
    processed_body = ' '.join(stemmed_words)

    return processed_body

# %% [markdown]
# Function to convert the geo references into geopoints

# %%
def extract_geopoints(georeferences):
    geolocator = Nominatim(user_agent="your_user_agent_here")
    coordinates = []

    for georef in georeferences:
        if georef and isinstance(georef, str):
            location = geolocator.geocode(georef)
            if location and hasattr(location, 'latitude') and hasattr(location, 'longitude'):
                coordinates.append((location.latitude, location.longitude))

    return coordinates

# %% [markdown]
# Function to extract and index all attributes

# %%
def index_document(title, content, authors, date, geopoint, temporal_expressions, georeferences):
    try:
        # Ensure that required fields have valid values before indexing
        if title and content and date and geopoint:
            document = {
                'title': title,
                'content': content,
                'authors': authors,
                'date': date,
                'geopoint': geopoint,
                'temporalExpressions': temporal_expressions,
                'georeferences': georeferences
            }

            # Index the document
            es.index(index='test_index', body=document)
            print(f"Document indexed successfully: {title}")
        else:
            print("Skipping document due to missing required fields.")
    except Exception as e:
        print(f"Error indexing document: {e}")

# Example usage:
# index_document("Sample Title", "Sample Content", ["Author1", "Author2"], "2023-01-01", "40.7128,-74.0060", "Some Temporal Expressions", "Some Georeferences")

# %%
def process_sgm_folder(folder_path):
    for filename in os.listdir(folder_path):
        if filename.endswith(".sgm"):
            file_path = os.path.join(folder_path, filename)
            process_sgm_file(file_path)

def process_sgm_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        
    soup = BeautifulSoup(content, 'html.parser')
    reuters_tags = soup.find_all('reuters')
    for reuters_tag in reuters_tags:      
        date=extract_date_of_publish(reuters_tag)
        print(date)
        authors=extract_authors(reuters_tag)
        print(authors)
        title = extract_article_title(reuters_tag)
        print(title)
        body = preprocess_body(reuters_tag)
        print(body)
        georeferences = extract_georeferences(reuters_tag)
        print(georeferences)
        temporal_expressions = extract_temporal_expressions(reuters_tag)
        if georeferences is not None:
            geopoints = extract_geopoints(georeferences)
            print(geopoints)
        
        #index_document(title, body, authors, date, geopoints, temporal_expressions, georeferences)        

data = "test_data"
process_sgm_folder(data)
# Out:
# 1987-02-26 15:01:01.790000
# None
# BAHIA COCOA REVIEW
# shower continu throughout week bahia cocoa zone allevi drought sinc earli januari improv prospect come temporao although normal humid level restor comissaria smith said weekli review dri period mean temporao late year arriv week end februari 155 221 bag kilo make cumul total season mln stage last year seem cocoa deliv earlier consign includ arriv figur comissaria smith said still doubt much old crop cocoa still avail harvest practic come end total bahia crop estim around mln bag sale stand almost mln hundr thousand bag still hand farmer middlemen export processor doubt much cocoa would fit export shipper experienc dificulti obtain bahia superior certif view lower qualiti recent week farmer sold good part cocoa held consign comissaria smith said spot bean price rose 340 350 cruzado per arroba kilo bean shipper reluct offer nearbi shipment limit sale book march shipment 750 780 dlr per tonn port name new crop sale also light open port june juli go 850 880 dlr dlr new york juli aug sept 870 875 880 dlr per tonn fob routin sale butter made march april sold 340 345 350 dlr april may butter went time new york may june juli 400 415 dlr aug sept 351 450 dlr time new york sept oct dec 480 dlr time new york dec comissaria smith said destin covert currenc area uruguay open port cake sale regist 785 995 dlr march april 785 dlr may 753 dlr aug time new york dec oct dec buyer argentina uruguay convert currenc area liquor sale limit march april sell 325 380 dlr june juli 375 dlr time new york juli aug sept 400 dlr time new york sept oct dec time new york dec comissaria smith said total bahia sale current estim mln bag 1986 crop mln bag 1987 crop final figur period februari expect publish brazilian cocoa trade commiss carniv end midday februari reuter
# ['New York', 'New York', 'New York Sept', 'New York Dec', 'U.S.', 'Uruguay', 'New York Dec', 'U.S.', 'Argentina', 'Uruguay', 'New York', 'New York Dec']
# [(40.7127281, -74.0060152), (40.7127281, -74.0060152), (44.3005113, -74.0796481), (46.822933750000004, 12.414190671411337), (-32.8755548, -56.0201525), (44.3005113, -74.0796481), (46.822933750000004, 12.414190671411337), (-34.9964963, -64.9672817), (-32.8755548, -56.0201525), (40.7127281, -74.0060152), (44.3005113, -74.0796481)]
# 1987-02-26 15:02:20
# None
# STANDARD OIL <SRD> TO FORM FINANCIAL UNIT
# standard oil north america inc said plan form ventur manag money market borrow invest activ compani north america subsidiari british petroleum plc also own pct interest standard oil ventur call standard financi trade oper standard oil oversight joint manag committe reuter
# ['North America\nInc', 'North America']
# [(35.771111649999995, -78.56463898908424), (51.0000002, -109.0)]
# 1987-02-26 15:03:27.510000
# None
# TEXAS COMMERCE BANCSHARES <TCB> FILES PLAN
# texa commerc bancshar inc texa commerc bank houston said file applic comptrol currenc effort creat largest bank network harri counti bank said network would link bank billion dlr asset billion dlr deposit reuter
# ['Texas', 'Harris County']
# [(31.2638905, -98.5456116), (29.8119769, -95.3741247)]
# 1987-02-26 15:07:13.720000
# [{'name': 'by Janie Gabbett, Reuters'}]
# TALKING POINT/BANKAMERICA <BAC> EQUITY OFFER
# none
# None
# 1987-02-26 15:43:59.530000
# None
# SENATORS INTRODUCE EXPORT LICENSING REFORM BILL
# sen alan cranston cal daniel evan wash said introduc export licens reform legisl could save compani hundr thousand dollar annual emphasi two fold decontrol licens item action endang nation secur elimin depart defens facto veto author licens process cranston said reform reduc licens requir pct told report convinc ration licens process boost export export control intend deni eastern bloc countri access technolog could militari capabl refocus control resourc higher level technolog technolog truli critic better job prevent divers critic technolog adversari promot export cranston said cannot expect continu play lead role new technolog develop futur unduli restrict activ firm world market place evan told report reuter
# ['Wash.', 'U.S.', 'U.S.', 'Eastern bloc', 'U.S.']
# [(47.2868352, -120.212613), (46.822933750000004, 12.414190671411337), (46.822933750000004, 12.414190671411337), (51.4698829, -0.0673691), (46.822933750000004, 12.414190671411337)]
# 1987-02-26 15:44:36.040000
# None
# EXCELAN INC SETS INITIAL STOCK OFFER
# excelan inc said make initi public offer 129 300 share common stock dlr per share excelan said mln share sold compani 529 300 share sold stockhold excelan design manufactur comput relat product reuter
# []
# []
# 1987-02-26 15:45:19.650000
# None
# CCX NETWORK <CCXN> SECONDARY OFFERING UNDERWAY
# ccx network inc said offer 220 838 share stock dlr share though underwrit stephen inc cazenov inc compani said sell stock behalf sharehold includ recent receiv share compani exchang busi compani said receiv proce offer reuter
# []
# []
# 1987-02-26 15:45:26.550000
# None
# FIRST UNION <FUNC> FILES 100 MLN DLR NOTES ISSUE
# first union corp said file secur exchang commiss propos offer 100 mln dlr fix rate subordin note due 1997 note sold nationwid underwrit manag shearson lehman brother inc reuter
# []
# []
# 1987-02-26 15:45:35.370000
# None
# OWENS AND MINOR INC <OBOD> RAISES QTLY DIVIDEND
# qtli div eight ct ct prior pay march record march reuter
# []
# []
# 1987-02-26 15:45:39.200000
# None
# COMPUTER LANGUAGE RESEARCH IN <CLRI> 4TH QTR
# shr loss ct loss ct net loss 035 000 loss 516 000 rev mln mln qtli div three ct three ct prior year shr profit two ct profit ct net profit 215 000 profit 647 000 rev mln mln note dividend payabl april one sharehold record march reuter
# []
# []
# 1987-02-26 15:45:47.290000
# None
# <CINRAM LTD> 4TH QTR NET
# shr ct ct net mln 829 000 sale mln mln avg shr 332 397 428 000 year shr dlr dlr net mln mln sale mln mln avg shr 332 397 428 000 reuter
# []
# []
# 1987-02-26 15:46:36.160000
# None
# DU PONT CO <DD> LAUNCHES IMPROVED ARAMID FIBERS
# pont said devlop new gener high strength aramid fiber stiffer less absorb previou gener pont said new product kevlar 149 pct stiffer first gener aramid absorb less half moister similar aramid fiber kevlar invent pont late 1960 five time stronger steel time stronger aluminum equal wieght basi use replac metal varieti product accord compani reuter
# []
# []
# 1987-02-26 15:47:16.170000
# None
# STANDARD TRUSTCO SEES BETTER YEAR
# standard trustco said expect earn 1987 increas least pct 140 000 dlr dlr per share record 1986 stabl interest rate grow economi expect provid favor condit growth 1987 presid brian malley told sharehold annual meet standard trustco previous report asset billion dlr 1986 billion dlr 1985 return common sharehold equiti pct last year pct 1985 reuter
# []
# []
# 1987-02-26 15:48:26.920000
# None
# HANDY AND HARMAN <HNH> 4TH QTR LOSS
# shr loss ct loss three ct net loss 041 000 loss 467 000 rev 138 mln 131 mln month shr loss ct profit ct net loss 843 000 profit 306 0000 rev 558 mln 556 mln note net loss 4th qtr 1986 includ charg restructur mln dlr tax ct share 1986 net loss includ tax special charg mln dlr ct share reuter
# []
# []
# 1987-02-26 15:49:27.160000
# None
# ICO PRODUCERS TO PRESENT NEW COFFEE PROPOSAL
# intern coffe organ ico produc countri present propos reintroduc export quota month april firm undertak tri negoti septemb futur quota distribut new basi ico deleg said distribut april would unchang basi earlier produc propos includ shortfal redistribut total mln bag said resumpt ico contact group meet consum schedul even postpon tomorrow deleg said reuter
# []
# []
# 1987-02-26 15:49:44.930000
# None
# SHULTZ SAYS NO RESIGNATION OVER IRAN REPORT
# secretari state georg shultz acknowledg fail iran arm affair declar would resign role scandal scar reagan administr attract harsh critic tower commiss report affair publish today shultz travel china week long visit refus comment directli report publish left washington repeat done sinc crisi broke last novemb go resign wipe slate said reuter
# ['Iran', 'China', 'Washington']
# [(2.9368696, 115.4443356), (30.047992, -94.3357433), (38.8950368, -77.0365427)]
# 1987-02-26 15:49:56.010000
# None
# MCLEAN'S <MII> U.S. LINES SETS ASSET TRANSFER
# mclean industri inc unit state line inc subsidiari said agre principl transfer south american servic arrang transfer certain charter asset crowley mariotim corp american transport line inc subsidiari line said negoti contract expect complet within next week term condit contract would subject approv variou regulatori bodi includ bankruptci court reuter
# []
# []
# 1987-02-26 15:51:17.840000
# [{'name': 'By Cal Mankowski, Reuters'}]
# CHEMLAWN <CHEM> RISES ON HOPES FOR HIGHER BIDS
# chemlawn corp chem could attract higher bid dlr per share offer wast manag inc wnx wall street arbitrageur said share chemlawn shot counter trade mln compani mln share chang hand late afternoon compani could time cash flow dlr mayb dollar depend whether compet bidder arbitrageur said wast manag tender offer announc open today expir march total surpris said debra strohmaier chemlawn spokeswoman compani board held regularli schedul meet today discuss wast manag announc said statement expect certain would readi unabl say prior contact wast manag chemlawn offici think resist said elliott schlang analyst prescott ball turben inc compani like surpris attack would arbitrageur point difficult resist tender offer share cash schlang said chemlawn could tri find white knight want acquir wast manag analyst rosemari morbelli ingal snyder said servicemast compani svm rollin inc rol exampl compani could interest chemlawn two mln custom largest compani involv applic fertil pesticid herbicid lawn wast manag involv remov wast schlang said chemlawn custom base could valuabl anoth compani want capit strong residenti commerci distribut system schlang morbelli note high growth rate catapult chemlawn share price mid 1983 stock languish rate growth slow schlang said compani profit concentr fourth quarter 1986 chemlawn earn dlr per share full year dlr fourth quarter morbelli note chemlawn compet thousand individu entrepreu offer lawn garden care sevic reuter
# ['U.S.', 'Schlang', 'Morbelli']
# [(46.822933750000004, 12.414190671411337), (47.7847701, 10.7543009), (42.0144542, 12.3751495)]
# 1987-02-26 15:51:28.420000
# None
# U.S. SUGAR IMPORTS DOWN IN WEEK - USDA
# sugar import subject sugar import quota week end januari initi week 1987 sugar quota year total 988 short ton versu 254 ton previou week agricultur depart said sugar import quota 1987 quota year januari decemb set 001 430 short ton compar 850 000 ton 1986 quota year extend three month decemb depart said custom servic report weekli cumul import report actual weight basi final polar receiv cumul import data adjust accordingli reuter
# ['U.S.']
# [(46.822933750000004, 12.414190671411337)]
# 1987-02-26 15:51:51.240000
# None
# BRAZIL ANTI-INFLATION PLAN LIMPS TO ANNIVERSARY
# inflat plan initi hail home abroad saviour economi limp toward first anniversari amid soar price widespread shortag foreign payment crisi announc last februari plan froze price fix valu new cruzado currenc end widespread index economi bid halt countri 250 pct inflat rate within year plan collaps situat wors although inflat least economi work lead bank economist said crumbl plan accompani dramat revers foreign trade account 1984 1985 brazil annual trade surplus suffici cover billion dlr need servic 109 billion dlr foreign debt first nine month 1986 seem target repeat monthli surplus averag one billion dlr export divert import increas avoid domest shortag trade surplu plung 211 mln dlr octob sinc averag 150 mln reuter
# ['Brazil']
# [(-10.3333333, -53.2)]
# 1987-02-26 15:52:15.100000
# None
# N.Z. OFFICIAL FOREIGN RESERVES FALL IN JANUARY
# new zealand offici foreign reserv fell billion dlr januari billion dlr decemb compar billion year ago period reserv bank said weekli statist bulletin reuter
# ["New Zealand's"]
# [(-36.8401002, 174.7467458)]
# 1987-02-26 15:52:25.600000
# None
# AGENCY REPORTS 39 SHIPS WAITING AT PANAMA CANAL
# panama canal commiss govern agenc said daili oper report backlog ship wait enter canal earli today next two day expect due schedul transit end day backlog averag wait time tomorrow super tanker regular vessel north end hr hr south end hr hr reuter
# ['U.S.']
# [(46.822933750000004, 12.414190671411337)]
# 1987-02-26 15:52:33.040000
# None
# AMERICA FIRST MORTGAGE SETS SPECIAL PAYOUT
# america first feder guarante mortgag fund two said make special distribut ct per exchang unit includ ct return capit ct incom gain reuter
# []
# []
# 1987-02-26 15:52:57.490000
# None
# REPUBLICANS EYE BIGGER U.S. CONSERVATION RESERVE
# group republican governor member congress said intend explor expand conserv reserv program mln acr current law mln acr erod land must enrol program end fiscal 1990 republican task forc farm rural america head senat major leader robert dole kan said would consid draft legisl increas reserv mln acr sen charl grassley iowa told reuter would offer bill expand reserv mln acr reuter
# ['Kan.', 'Iowa']
# [(38.27312, -98.5821872), (41.9216734, -93.3122705)]
# 1987-02-26 15:53:05.480000
# None
# ARVIN INDS <ARV> PROMOTES EVANS TO PRESIDENT
# arvin industri inc said evan elect presid succeed jame baker remain chairman evan execut vice presid reuter
# []
# []
# 1987-02-26 15:53:54.560000
# None
# EMHART CORP <EMH> QTLY DIVIDEND
# qtli div ct ct prior payabl march record march nine reuter
# []
# []
# 1987-02-26 15:54:55.200000
# [{'name': 'By Kathleen Hays, Reuters'}]
# U.S. DATA POINT TO CAPITAL SPENDING SLOWDOWN
# surpris pct drop januari durabl good order point slowdown capit spend could presag lacklust real growth economi first quarter 1987 economist said total order exclud volatil defens sector fall record pct economist agre report paint bleak pictur economi stress 1987 tax reform law may primari factor behind drop order busi capit invest rather gloomi outlook economi said david wyss data resourc inc particularli impress pct drop non defens capit good order may sign busi react advers tax reform thought commerc depart point record pct declin new order machineri led declin offic comput equip order economist said drop comput order may respons lengthen depreci schedul end invest tax credit new tax law expens invest use peopl much wyss said increas durabl good order year end reinforc view busi anticip chang tax law economist said novemb durabl good order rose pct decemb increas pct revis upward previous report pct
# ['Elkhart', 'Ind.']
# [(41.6012796, -85.8590603), (40.3270127, -86.1746933)]
# 1987-02-26 16:12:01.460000
# None
# TULTEX CORP <TTX> SETS QUARTERLY DIVIDEND
# qtli div eight ct eight ct prior pay april one record march reuter
# []
# []
# 1987-02-26 16:13:04.200000
# None
# BURLINGTON <BUR>  GETS 30.5 MLN DLR CONTRACT
# burlington menswear new york citi divis burlington industri inc receiv mln dlr defens contract mln yard tropic cloth defens logist agenc said reuter
# ['New York City']
# [(40.7127281, -74.0060152)]
# 1987-02-26 16:13:36.470000
# None
# ROCKWELL <ROK> GETS 28.3 MLN DLR B-1 CONTRACT
# rockwel intern corp receiv mln dlr contract work bomber current fiscal year air forc said reuter
# []
# []
# 1987-02-26 16:14:23.260000
# None
# ATICO FINANCIAL CORP <ATFC> 4TH QTR NET
# shr ct dlr net 142 000 mln rev mln mln year shr ct dlr net 320 000 mln rev mln mln note 1986 4th qtr amount includ acquisit pct common atico formerli peninsula feder save loan associ januari 1986 1985 4th qtr net includ net gain mln dlr dlr per share exchang common pan america bank inc common ncnb corp purus merger compani reuter
# ['Atico']
# [(-16.2084572, -73.6232865)]
# 1987-02-26 16:15:51.340000
# None
# ICO EXPORTERS TO MODIFY NEW PROPOSAL
# intern coffe organ ico export modifi new propos quota resumpt present import tomorrow ico deleg said chang discuss tonight inform among produc follow talk formal produc session eight member produc splinter group affect propos quota distribut month april one said propos share would still includ shortfal declar said reuter
# []
# []
# 1987-02-26 16:16:52.920000
# None
# U.S. COMMERCIAL PAPER FALLS 375 MLN DLRS IN FEB 18 WEEK, FED SAYS
# none
# None
# 1987-02-26 16:17:05.960000
# None
# N.Y. BUSINESS LOANS FALL 195 MLN DLRS IN FEB 18 WEEK, FED SAYS
# none
# None
# 1987-02-26 16:17:21.410000
# None
# NEW YORK BANK DISCOUNT WINDOW BORROWINGS 64 MLN DLRS IN FEB 25 WEEK
# none
# None
# 1987-02-26 16:18:41.470000
# [{'name': 'By Jane Arraf, Reuters'}]
# QUEBECOR <PQB> HEAD SEES NEW VENTURES LIKELY
# ...
# amr corp hold press confer morn new york 0900 est compani spokesman said would comment subject press confer would confirm publish report amr today announc billion dlr purchas aircraft engin accord new york time report amr expect announc purchas widebodi longrang a300 airbu industri boe 767 choic gener electr suppli engin craft engin order alon cf80c would worth 500 mln dlr airbu plane order would worth billion dlr boe order 750 mln dlr accord report reuter
# ['New York']
# [(40.7127281, -74.0060152)]
# 1987-03-03 08:30:18.430000
# None
# UNILEVER IMPROVES IN MOST SECTORS DURING 1986
# unilev plc group saw improv perform almost sector 1986 anglo dutch group said result statement good progress made last year recent acquisit chesebrough pond inc cbm signific addit greatli benefit group year come earlier unilev report combin fourth quarter pre tax profit 276 mln stg level year earlier period make billion stg compar 953 mln 1986 full year unilev said plan chang depreci polici convent practic depreci asset individu rather depreci fix asset averag rate new method expect lead reduct accumul provis depreci therebi increas net book valu tangibl assset 300 mln stg januari 1987 unilev plc share 25p sinc yesterday 575p buoyant respons result share split propos though 1986 profit ahead market forecast dealer ad reuter
# []
# []
# 1987-03-03 08:31:03.090000
# None
# U.S. LEADING INDICATORS FELL 1.0 PCT IN JAN AFTER REVISED 2.3 PCT DEC RISE
# none
# None
# 1987-03-03 08:33:35.390000
# None
# AMR CORP ORDERS 40 JETS FROM AIRBUS AND BOEING
# none
# None
# 1987-03-03 08:35:15.780000
# None
# U.S. LEADING INDEX FELL 1.0 PCT IN JANUARY
# index lead indic fell season adjust pct januari revis pct decemb gain commerc depart said depart previous said index rose pct decemb declin januari biggest month sinc juli 1984 index fell pct januari decreas left index 183 1967 base 100 led fall contract order plant equip total six indic avail januari contribut declin besid contract order plant equip build permit manufactur new order consum good chang sensit materi price slower deliveri vendor higher averag weekli claim state unemploy insur four indic posit includ stock price new busi format averag work week money suppli main factor decemb upward revis new busi format revis pct increas lead indic index novemb index coincid indic measur current economi fell pct januari increas pct decemb pct novemb index lag indic measur past econom activ rose pct januari decreas pct decemb increas pct novemb reuter
# ['U.S.']
# [(46.822933750000004, 12.414190671411337)]
# 1987-03-03 08:35:23.450000
# None
# BRAZIL FINANCE MINISTER MEETS FRENCH OFFICIALS
# brazilian financ minist dilson funaro held separ meet french financ minist edouard balladur bank franc governor jacqu larosier second stage european mission explain countri latest debt crisi french offici said declin disclos detail talk monetari sourc describ preliminari diplomat effort see franc could help negoti financi concess sought brazil western bank govern offici lend agenc reuter
# ['France', 'Brazil']
# [(46.603354, 1.8883335), (-10.3333333, -53.2)]
# 1987-03-03 08:35:28.550000
# None
# BURLINGTON COAT FACTORY WAREHOUSE CORP <BCF> NET
# jan end shr dlr dlr net mln mln rev 196 mln 157 mln reuter
# []
# []
# 1987-03-03 08:42:08.500000
# None
# COFFEE PRICE FALL SHORT TERM - DUTCH ROASTERS
# morn sharp declin coffe price follow breakdown late last night negoti london reintroduc intern coffe organ ico quota short live dutch roaster said fall technic emot reaction failur agre reintroduct ico export quota long realiti reassert price rise spokesman one major dutch roaster said fact ampl suppli coffe avail present shortag qualiti said averag price fell around 110 cent follow news breakdown expect move back around 120 cent within week roaster ad dutch coffe roaster associ secretari jan vri said although roaster disappoint failur consum produc ico repres agre quota reintroduct equal import quota realloc equit basi absolut need quota moment market well balanc must lose opportun renegoti coffe agreement said still lot work done number claus intern coffe agreement would welcom quota reintroduct complet renegoti vri ad mind dutch roaster claim fairli good forward cover buy strategi forese futur would probabl buy coffe hand mouth basi slide scale market price 120 cent roaster said reuter
# ['London']
# [(51.4893335, -0.14405508452768728)]
# 1987-03-03 08:44:34.430000
# None
# GREENWOOD RESOURCES <GRRL> SELLS COMPANY STAKE
# greenwood resourc inc said sold 300 000 common share major hold new london oil ltd london affili guin peat group plc london affili sidro belgium total 700 0000 dlr cash compani said appli proce sale support line credit part propos debt restructur colorado nation bancshar colc greenwood sharehold said retain seat new london board reuter
# ['London', 'London', 'Belgium', 'New London']
# [(51.4893335, -0.14405508452768728), (51.4893335, -0.14405508452768728), (50.6402809, 4.6667145), (41.3556187, -72.0997804)]
# 1987-03-03 08:47:17.780000
# None
# AMR <AMR> TO ACQUIRE 40 LONG-RANGE JET AIRCRAFT
# want japan elimin import control agricultur product within three year visit secretari state econom affair allen walli told eishiro saito chairman feder econom organis keidanren spokesman keidanren said spokesman quot walli say drastic measur would need stave protectionist legisl congress walli attend sub cabinet level bilater trade meet made remark yesterday talk saito walli quot say reagan administr want japanes cooper white hous ensur trade bill moder one rather contain retaliatori measur antagonis particular countri also quot say would pleas japan halv restrict agricultur import within five year countri cannot cope abolit within three spokesman said japan current restrict import agricultur product ban rice import trigger recent complaint japan agricultur polici reuter
# ['U.S.', 'Japan', 'U.S.', 'U.S.', 'U.S.', 'Japan', 'Japan', 'U.S.', 'Japan']
# [(46.822933750000004, 12.414190671411337), (36.5748441, 139.2394179), (46.822933750000004, 12.414190671411337), (46.822933750000004, 12.414190671411337), (46.822933750000004, 12.414190671411337), (36.5748441, 139.2394179), (36.5748441, 139.2394179), (46.822933750000004, 12.414190671411337), (36.5748441, 139.2394179)]
# 1987-03-03 09:13:24.260000
# None
# U.S. FINANCIAL ANALYSTS - March 3
# new york sarich technolog trust new york health manag associ new york reuter
# []
# []
# 1987-03-03 09:13:27.600000
# None
# None
# none
# None
# 1987-03-03 09:13:32.690000
# None
# None
# none
# None
# 1987-03-03 09:14:40.200000
# None
# FIRSTCORP <FCR> SEES GAIN ON CONDEMNATION
# firstcorp inc said weill report tax gain 827 000 dlr ct per share primari ct fulli dilut propos condemn acquisit park deck oper wake counti compani said reinvest proce similar properti within month gain sale would defer tax purpos reuter
# ['Wake County']
# [(35.7979355, -78.6118311)]
# 1987-03-03 09:15:05.400000
# None
# ASHTON-TATE <TATE> TO OFFER COMMON SHARES
# ashton tate said intend file offer two mln share within next day said proce would use work capit gener corpor purpos includ possibl acquisit busi addit technolog ashton tate mln share outstand reuter
# []
# []
# 1987-03-03 09:15:33.280000
# None
# KEYCORP <KEY> REGISTERS SUBORDINATED NOTES
# keycorp said file secur exchang commiss offer mln dlr subordin capit note due march 1999 compani said anticip note offer week underwrit led first boston corp proce use gener corpor purpos includ acquisit seattl trust save bank schedul juli one keycorp said reuter
# []
# []
# 1987-03-03 09:15:47.270000
# None
# <NATIONAL SEA PRODUCTS LTD> 4TH QTR NET
# oper shr ct ct oper net 846 000 386 000 rev 137 mln 107 mln year oper shr dlr ct oper net 764 000 239 000 rev 516 mln 454 mln note 1986 qtr exclud extraordinari gain 784 000 dlr five ct share versu extraordinari loss 110 000 dlr shr nil 1985 qtr note continu 1986 year exclud extraordinari gain 360 000 dlr ct share versu extraordinari gain 883 000 dlr ct share prior year reuter
# []
# []
# 1987-03-03 09:16:02.850000
# None
# U.K. MONEY MARKET SHORTAGE FORECAST REVISED DOWN
# bank england said revis forecast shortag money market 450 mln stg take account morn oper noon bank estim shortfal 500 mln stg reuter
# []
# []
# 1987-03-03 09:17:32.300000
# None
# NATIONAL AMUSEMENTS AGAIN UPS VIACOM <VIA> BID
# viacom intern inc said nation amus inc rais valu offer viacom publicli held stock compani said special committe board plan meet later today consid offer one submit march one mcv hold inc spokeswoman unabl say committe met plan yesterday viacom said nation amus arsen hold inc subsidiari rais amount cash offer viacom share ct dlr valu fraction share exchang arsen hold prefer includ rais ct dlr nation amus alreadi own pct viacom stock reuter
# []
# []
